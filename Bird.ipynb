# %% [markdown]
# <a href="https://colab.research.google.com/github/CyntiaMCP/RP/blob/main/Bird.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nueva sección

# %%
import pandas as pd
import sklearn as skl

# %%
dataframe = pd.read_csv('dataset.csv')
print(dataframe)

# %%
dataframe = pd.read_csv('dataset_norm.csv')
print(dataframe)
# Out:
#       chroma_stft       rms  spectral_centroid  spectral_bandwidth   rolloff  \
# 0        0.438129 -0.127808          -0.033283           -0.121215  0.001517
# 1        0.079270 -0.416530          -0.789508           -0.930725 -1.119066
# 2       -0.262189  1.240163           0.034783           -0.184716 -0.212817
# 3       -0.904751  1.162465           0.289642           -0.542112 -0.201405
# 4       -0.276736 -0.139651           0.219158            0.027327 -0.029960
# ...           ...       ...                ...                 ...       ...
# 2145    -0.885905 -0.919137           0.312847           -1.091073 -0.126217
# 2146    -0.750820  0.293521          -0.128589           -0.382103 -0.287986
# 2147     0.880661  1.060579          -1.322595           -0.232854 -1.203739
# 2148    -0.601642 -0.391649           0.776751            0.160094  0.776761
# 2149    -1.721097  0.192648           0.930236           -1.221106  0.187378
#
# ...

# %%
print(dataframe.describe())
# Out:
#        chroma_stft          rms  spectral_centroid  spectral_bandwidth  \
# count  2150.000000  2150.000000        2150.000000         2150.000000
# mean      0.454948     0.023054        3269.452352         2166.964439
# std       0.108559     0.022133         970.857607          407.895336
# min       0.039548     0.000434         567.364605          224.051085
# 25%       0.378742     0.008579        2616.566390         1897.728494
# 50%       0.450333     0.016948        3248.338065         2167.619707
# 75%       0.528923     0.029864        3916.510382         2448.353113
# max       0.901490     0.298023        6528.137577         3876.705602
#
#            rolloff  zero_crossing_rate        mfcc1        mfcc2        mfcc3  \
# count  2150.000000         2150.000000  2150.000000  2150.000000  2150.000000
# mean   5407.360177            0.232915  -404.083122    31.018037   -23.460955
# std    1345.169746            0.107588    90.242596    59.375765    42.049935
# ...

# %%
label = dataframe[['Unnamed: 27']]
print(label.head(10))
# Out:
#   Unnamed: 27
# 0    Pajaro01
# 1    Pajaro01
# 2    Pajaro01
# 3    Pajaro01
# 4    Pajaro01
# 5    Pajaro01
# 6    Pajaro01
# 7    Pajaro01
# 8    Pajaro01
# 9    Pajaro01

# %%
from sklearn.preprocessing import OrdinalEncoder
ordinal_encoder = OrdinalEncoder()
label_encoded = ordinal_encoder.fit_transform(label)
print(label_encoded[:5])
# Out:
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]]

# %%
dataframe = dataframe.drop(['filename'],axis=1)

# %%
dataframe.rename(columns={'Unnamed: 27': 'Especie'}, inplace=True)

# %%
dataframe
# Out:
#       chroma_stft       rms  spectral_centroid  spectral_bandwidth  \
# 0        0.502511  0.020225        3237.139463         2117.521235
# 1        0.463554  0.013834        2502.952694         1787.326026
# 2        0.426485  0.050502        3303.221447         2091.619472
# 3        0.356730  0.048783        3550.653243         1945.839632
# 4        0.424906  0.019963        3482.223598         2178.110807
# ...           ...       ...                ...                 ...
# 2145     0.358775  0.002710        3573.182484         1721.920782
# 2146     0.373440  0.029550        3144.610843         2011.106375
# 2147     0.550552  0.046527        1985.401211         2071.984403
# 2148     0.389635  0.014385        4023.567006         2232.266141
# 2149     0.268108  0.027317        4172.579232         1668.880905
#
#           rolloff  zero_crossing_rate       mfcc1      mfcc2      mfcc3  \
# 0     5409.400623            0.244248 -348.926148  37.630703 -37.522160
# ...

# %% [markdown]
# Maximo minimo

# %%
from sklearn import preprocessing

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
transformed_iris = scaler.fit_transform(dataframe.iloc[:, :26])

transformed_iris = pd.DataFrame(transformed_iris)
#transformed_iris["Especie"] = dataframe["Especie"]
#transformed_iris.columns = dataframe.columns

# %%
transformed_iris
# Out:
#             0         1         2         3         4         5         6   \
# 0     0.537116  0.066504  0.447891  0.518382  0.559209  0.389594  0.654372
# 1     0.491919  0.045030  0.324721  0.427983  0.401949  0.302674  0.618522
# 2     0.448914  0.168246  0.458977  0.511291  0.529130  0.400399  0.838981
# 3     0.367985  0.162468  0.500487  0.471380  0.530731  0.448588  0.788610
# 4     0.447081  0.065623  0.489007  0.534970  0.554791  0.394452  0.732016
# ...        ...       ...       ...       ...       ...       ...       ...
# 2145  0.370358  0.007649  0.504266  0.410077  0.541283  0.557219  0.389387
# 2146  0.387372  0.097840  0.432368  0.489248  0.518580  0.409822  0.750892
# 2147  0.592852  0.154890  0.237895  0.505915  0.390066  0.091237  0.558113
# 2148  0.406160  0.046881  0.579825  0.549796  0.668004  0.499200  0.453456
# 2149  0.265169  0.090338  0.604823  0.395556  0.585292  0.586990  0.499882
#
# ...

# %%
label = pd.DataFrame(label_encoded)

# %%
data = pd.concat([transformed_iris, label], axis=1,)

# %%
data
# Out:
#             0         1         2         3         4         5         6   \
# 0     0.537116  0.066504  0.447891  0.518382  0.559209  0.389594  0.654372
# 1     0.491919  0.045030  0.324721  0.427983  0.401949  0.302674  0.618522
# 2     0.448914  0.168246  0.458977  0.511291  0.529130  0.400399  0.838981
# 3     0.367985  0.162468  0.500487  0.471380  0.530731  0.448588  0.788610
# 4     0.447081  0.065623  0.489007  0.534970  0.554791  0.394452  0.732016
# ...        ...       ...       ...       ...       ...       ...       ...
# 2145  0.370358  0.007649  0.504266  0.410077  0.541283  0.557219  0.389387
# 2146  0.387372  0.097840  0.432368  0.489248  0.518580  0.409822  0.750892
# 2147  0.592852  0.154890  0.237895  0.505915  0.390066  0.091237  0.558113
# 2148  0.406160  0.046881  0.579825  0.549796  0.668004  0.499200  0.453456
# 2149  0.265169  0.090338  0.604823  0.395556  0.585292  0.586990  0.499882
#
# ...

# %%
data.to_csv('dataset_cl.csv')

# %% [markdown]
# # Modelado

# %% [markdown]
# MODELOS

# %%
data2 = pd.read_csv('dataset_norm.csv')

# %%
data3 = pd.read_csv('dataset_nn.csv')

# %%
data3
# Out:
#       chroma_stft       rms  spectral_centroid  spectral_bandwidth  \
# 0        0.502511  0.020225        3237.139463         2117.521235
# 1        0.463554  0.013834        2502.952694         1787.326026
# 2        0.426485  0.050502        3303.221447         2091.619472
# 3        0.356730  0.048783        3550.653243         1945.839632
# 4        0.424906  0.019963        3482.223598         2178.110807
# ...           ...       ...                ...                 ...
# 2145     0.358775  0.002710        3573.182484         1721.920782
# 2146     0.373440  0.029550        3144.610843         2011.106375
# 2147     0.550552  0.046527        1985.401211         2071.984403
# 2148     0.389635  0.014385        4023.567006         2232.266141
# 2149     0.268108  0.027317        4172.579232         1668.880905
#
#           rolloff  zero_crossing_rate       mfcc1      mfcc2      mfcc3  \
# 0     5409.400623            0.244248 -348.926148  37.630703 -37.522160
# ...

# %%
data
# Out:
#       chroma_stft       rms  spectral_centroid  spectral_bandwidth   rolloff  \
# 0        0.537116  0.066504           0.447891            0.518382  0.559209
# 1        0.491919  0.045030           0.324721            0.427983  0.401949
# 2        0.448914  0.168246           0.458977            0.511291  0.529130
# 3        0.367985  0.162468           0.500487            0.471380  0.530731
# 4        0.447081  0.065623           0.489007            0.534970  0.554791
# ...           ...       ...                ...                 ...       ...
# 2145     0.370358  0.007649           0.504266            0.410077  0.541283
# 2146     0.387372  0.097840           0.432368            0.489248  0.518580
# 2147     0.592852  0.154890           0.237895            0.505915  0.390066
# 2148     0.406160  0.046881           0.579825            0.549796  0.668004
# 2149     0.265169  0.090338           0.604823            0.395556  0.585292
#
# ...

# %%
feature_list = list(data.columns)
feature_list.remove('Especie')

# %%
feature_list = list(data2.columns)
feature_list.remove('Especie')

# %%
feature_list2 = list(data3.columns)
feature_list2.remove('Especie')

# %%
X2=data3[feature_list2]
X2
# Out:
#       chroma_stft       rms  spectral_centroid  spectral_bandwidth  \
# 0        0.502511  0.020225        3237.139463         2117.521235
# 1        0.463554  0.013834        2502.952694         1787.326026
# 2        0.426485  0.050502        3303.221447         2091.619472
# 3        0.356730  0.048783        3550.653243         1945.839632
# 4        0.424906  0.019963        3482.223598         2178.110807
# ...           ...       ...                ...                 ...
# 2145     0.358775  0.002710        3573.182484         1721.920782
# 2146     0.373440  0.029550        3144.610843         2011.106375
# 2147     0.550552  0.046527        1985.401211         2071.984403
# 2148     0.389635  0.014385        4023.567006         2232.266141
# 2149     0.268108  0.027317        4172.579232         1668.880905
#
#           rolloff  zero_crossing_rate       mfcc1      mfcc2      mfcc3  \
# 0     5409.400623            0.244248 -348.926148  37.630703 -37.522160
# ...

# %%
X=data2[feature_list]

# %%
X
# Out:
#       chroma_stft       rms  spectral_centroid  spectral_bandwidth   rolloff  \
# 0        0.438129 -0.127808          -0.033283           -0.121215  0.001517
# 1        0.079270 -0.416530          -0.789508           -0.930725 -1.119066
# 2       -0.262189  1.240163           0.034783           -0.184716 -0.212817
# 3       -0.904751  1.162465           0.289642           -0.542112 -0.201405
# 4       -0.276736 -0.139651           0.219158            0.027327 -0.029960
# ...           ...       ...                ...                 ...       ...
# 2145    -0.885905 -0.919137           0.312847           -1.091073 -0.126217
# 2146    -0.750820  0.293521          -0.128589           -0.382103 -0.287986
# 2147     0.880661  1.060579          -1.322595           -0.232854 -1.203739
# 2148    -0.601642 -0.391649           0.776751            0.160094  0.776761
# 2149    -1.721097  0.192648           0.930236           -1.221106  0.187378
#
# ...

# %% [markdown]
# TEST
#
# L1

# %%
X = preprocessing.normalize(X, norm='l1')

# %%
X = pd.DataFrame(X)

# %% [markdown]
# L2

# %%
X = preprocessing.normalize(X, norm='l2')

# %%
X = pd.DataFrame(X)

# %%
y=data2['Especie']

# %%
y
# Out:
# 0       Pajaro01
# 1       Pajaro01
# 2       Pajaro01
# 3       Pajaro01
# 4       Pajaro01
#           ...
# 2145    Pajaro50
# 2146    Pajaro50
# 2147    Pajaro50
# 2148    Pajaro50
# 2149    Pajaro50
# Name: Especie, Length: 2150, dtype: object

# %%
y2=data3['Especie']
y2
# Out:
# 0       Pajaro01
# 1       Pajaro01
# 2       Pajaro01
# 3       Pajaro01
# 4       Pajaro01
#           ...
# 2145    Pajaro50
# 2146    Pajaro50
# 2147    Pajaro50
# 2148    Pajaro50
# 2149    Pajaro50
# Name: Especie, Length: 2150, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %% [markdown]
# Regresión Log.

# %%
from sklearn.linear_model import LogisticRegression

logisticRegrIris = LogisticRegression(max_iter=1000)

# %%
logisticRegrIris.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
logisticRegrIris.score(X_test, y_test)
# Out:
# 0.351937984496124

# %% [markdown]
# Árbol de decisión

# %%
from sklearn import tree

# %%
Dt_model = tree.DecisionTreeClassifier(max_leaf_nodes = 10)

# %%
Dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_leaf_nodes=10)

# %%
Dt_model.score(X_test, y_test)
# Out:
# 0.08682170542635659

# %%
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

y_pred = Dt_model.predict(X_test)
matriz = confusion_matrix(y_test,y_pred)

plot_confusion_matrix(conf_mat=matriz, figsize=(6,6), show_normed=False)
plt.tight_layout()

# %% [markdown]
# SVM

# %%
from sklearn import datasets, svm, metrics
clf = svm.SVC(kernel='rbf')

# %%
clf.fit(X_train, y_train)
# Out:
# SVC()

# %%
clf.score(X_train, y_train)
# Out:
# 0.6146179401993356

# %% [markdown]
# BEST PARM.

# %%
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.svm import SVC

C_range = np.logspace(-2, 2, 5)
gamma_range = np.logspace(-2, 2, 5)
param_grid = dict(gamma=gamma_range, C=C_range)

cv = StratifiedShuffleSplit(n_splits=5, test_size=0.3, random_state=42)
grid = GridSearchCV(SVC(), param_grid=param_grid, cv=cv)
grid.fit(X, y)

print(
    "The best parameters are %s with a score of %0.2f"
    % (grid.best_params_, grid.best_score_)
)
# Out:
# The best parameters are {'C': 100.0, 'gamma': 0.01} with a score of 0.40

# %%
gamma_range
# Out:
# array([1.00000000e-05, 1.29154967e-04, 1.66810054e-03, 2.15443469e-02,
#        2.78255940e-01, 3.59381366e+00, 4.64158883e+01, 5.99484250e+02,
#        7.74263683e+03, 1.00000000e+05])

# %% [markdown]
# NORM

# %%
from sklearn import datasets, svm, metrics
clf = svm.SVC(kernel='rbf', C=35.93813663804626, gamma=0.01291549665014884)

# %%
clf.fit(X_train, y_train)
clf.score(X_train, y_train)
# Out:
# 0.9541528239202658

# %%
from sklearn import datasets, svm, metrics
clf = svm.SVC(kernel='rbf', C=12.915496650148826, gamma=0.027825594022071243)

# %%
clf.fit(X_train, y_train)
clf.score(X_train, y_train)
# Out:
# 0.9700996677740864

# %% [markdown]
# Polinomial

# %%
from sklearn import datasets, svm, metrics
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

poly_kernel_svm = Pipeline([
    ('scaler',StandardScaler()),
    ('svm_clf',SVC(kernel='poly',degree=3,coef0=1,C=5))
])

# %%
poly_kernel_svm.fit(X2, y2)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm_clf', SVC(C=5, coef0=1, kernel='poly'))])

# %%
poly_kernel_svm.score(X2, y2)
# Out:
# 0.9883720930232558

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from numpy import *
random.seed(1234)

# %%
clf=RandomForestClassifier(max_depth=1000, random_state=0)
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=1000, random_state=0)

# %%
y_pred=clf.predict(X_test)

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.3178294573643411

# %% [markdown]
# Test
